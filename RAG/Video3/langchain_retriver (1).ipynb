# %%
# !pip install langchain chromadb faiss-cpu openai tiktoken langchain_openai langchain-community wikipedia langchain_google_genai
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.0/52.0 kB 1.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.4/21.4 MB 58.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.8/23.8 MB 69.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.9/84.9 kB 6.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 88.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.5/66.5 kB 4.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.2/278.2 kB 18.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 70.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 45.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 496.3/496.3 kB 29.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 81.2 MB/s eta 0:00:00
# ...

# %%
from langchain_community.retrievers import WikipediaRetriever

# %%
ret=WikipediaRetriever(top_n_documents=2,lang='en')

# %%
query="Pakistan Vs India Population"
res=ret.invoke(query)
print(res)
# Out:
# [Document(metadata={'title': 'India–Pakistan cricket rivalry', 'summary': "The India–Pakistan cricket rivalry is one of the most intense sports rivalries in the world. Matches between the teams are considered some of the biggest in the world and are among the most-viewed in all of sports.\nThe two teams have played a total of 211 times, with Pakistan winning 88 matches and India winning 80. In Tests and ODIs, Pakistan has been victorious in more games than India, while India has won more games in T20Is. In ICC World Cups, the two sides have met head to head in 16 matches, with India winning 15 of them. Both India and Pakistan have won the ICC Cricket World Cup, the ICC T20 World Cup, as well as other prestigious tournaments. In fact, India has won seven ICC trophies, while Pakistan has won three ICC trophies.\nThe tense relations between the two nations, resulting from bitter diplomatic relations and conflict that originated during the Partition of British India into India and Pakist
# ...

# %%
for i, doc in enumerate(res):
  print("Document No :",i+1)
  print(doc.page_content)
# Out:
# Document No : 1
# The India–Pakistan cricket rivalry is one of the most intense sports rivalries in the world. Matches between the teams are considered some of the biggest in the world and are among the most-viewed in all of sports.
# The two teams have played a total of 211 times, with Pakistan winning 88 matches and India winning 80. In Tests and ODIs, Pakistan has been victorious in more games than India, while India has won more games in T20Is. In ICC World Cups, the two sides have met head to head in 16 matches, with India winning 15 of them. Both India and Pakistan have won the ICC Cricket World Cup, the ICC T20 World Cup, as well as other prestigious tournaments. In fact, India has won seven ICC trophies, while Pakistan has won three ICC trophies.
# ...

# %% [markdown]
# Vector Base Retrivers

# %%
# !pip install langchain_chroma

# %%
from langchain_google_genai import ChatGoogleGenerativeAI,GoogleGenerativeAIEmbeddings
from langchain_chroma import Chroma

# %%
from langchain_core.documents import Document

# 1. Define PSL-themed content and rich metadata
docs = [
    Document(
        page_content="Islamabad United is the only team to have won the PSL title three times (2016, 2018, 2024).",
        metadata={"team": "Islamabad United", "city": "Islamabad", "stat_type": "championships", "source": "psl_history.pdf"}
    ),
    Document(
        page_content="Babar Azam is the highest run-scorer in the history of PSL, known for his consistent cover drives.",
        metadata={"player": "Babar Azam", "role": "Batsman", "stat_type": "records", "source": "player_stats.csv"}
    ),
    Document(
        page_content="The 2024 PSL Final was held at the National Bank Stadium in Karachi, where United beat Multan Sultans.",
        metadata={"year": 2024, "venue": "Karachi", "event": "Final", "source": "match_reports"}
    ),
    Document(
        page_content="Shaheen Shah Afridi led Lahore Qalandars to back-to-back titles in 2022 and 2023.",
        metadata={"team": "Lahore Qalandars", "captain": "Shaheen Afridi", "stat_type": "leadership", "source": "psl_archives"}
    ),
    Document(
        page_content="Peshawar Zalmi's 'Yellow Storm' fan base is considered one of the most passionate in the league.",
        metadata={"team": "Peshawar Zalmi", "city": "Peshawar", "category": "fan_culture", "source": "social_media_analysis"}
    )
]

# Verify the Islamabad doc
print(f"Team: {docs[0].metadata['team']}")
print(f"Fact: {docs[0].page_content}")
# Out:
# Team: Islamabad United
# Fact: Islamabad United is the only team to have won the PSL title three times (2016, 2018, 2024).

# %%
embeddings = GoogleGenerativeAIEmbeddings(model="gemini-embedding-001",google_api_key='-')

# %%
vector_store=Chroma.from_documents(documents=docs,embedding=embeddings,persist_directory='my_chromaDB',collection_name='sample')

# %%
vector_store.get()
# Out:
# {'ids': ['a7b178e5-36c6-40f9-a94c-aa35cc582145',
#   'fa1adb3e-0542-42a4-b6da-88eb8872133a',
#   '9c73cc07-1dad-4b3b-8995-a179df24912f',
#   '437630dc-0833-49b9-b0ca-ef1935c9fbed',
#   '1637ae07-21bd-4a67-9490-0d58439203fc'],
#  'embeddings': None,
#  'documents': ['Islamabad United is the only team to have won the PSL title three times (2016, 2018, 2024).',
#   'Babar Azam is the highest run-scorer in the history of PSL, known for his consistent cover drives.',
#   'The 2024 PSL Final was held at the National Bank Stadium in Karachi, where United beat Multan Sultans.',
#   'Shaheen Shah Afridi led Lahore Qalandars to back-to-back titles in 2022 and 2023.',
#   "Peshawar Zalmi's 'Yellow Storm' fan base is considered one of the most passionate in the league."],
#  'uris': None,
#  'included': ['metadatas', 'documents'],
#  'data': None,
#  'metadatas': [{'team': 'Islamabad United',
#    'city': 'Islamabad',
#    'stat_type': 'championships',
#    'source': 'psl_history.pdf'},
# ...

# %%
query="what is islamabad united"

# %%
res=vector_store.as_retriever(search_kwargs={"k":2})

# %%
result=res.invoke(query)

# %%
print(result[0].page_content)
# Out:
# Islamabad United is the only team to have won the PSL title three times (2016, 2018, 2024).

# %%
print(result[1].page_content)
# Out:
# The 2024 PSL Final was held at the National Bank Stadium in Karachi, where United beat Multan Sultans.

# %% [markdown]
# MMR

# %%
# Sample documents
docs = [
    Document(page_content="LangChain makes it easy to work with LLMs."),
    Document(page_content="LangChain is used to build LLM based applications."),
    Document(page_content="Chroma is used to store and search document embeddings."),
    Document(page_content="Embeddings are vector representations of text."),
    Document(page_content="MMR helps you get diverse results when doing similarity search."),
    Document(page_content="LangChain supports Chroma, FAISS, Pinecone, and more."),
]

# %%
from langchain_chroma import Chroma

# %%
embeddings = GoogleGenerativeAIEmbeddings(model="gemini-embedding-001",google_api_key='-')

# %%
vector_store=Chroma.from_documents(documents=docs,embedding=embeddings,persist_directory='my_chromaDB',collection_name='sample')

# %%
from re import search
res=vector_store.as_retriever(search_type='mmr',search_kwargs={"k":3,"lambda_mult":0})

# %%
query="what is langchain"

# %%
results=res.invoke(query)

# %%
print(results)
# Out:
# [Document(id='53a1acab-9b50-49d8-aa00-418fa7caa0a5', metadata={}, page_content='LangChain is used to build LLM based applications.'), Document(id='2bf2d60a-f493-4329-92ad-1c757e289481', metadata={}, page_content='MMR helps you get diverse results when doing similarity search.'), Document(id='1637ae07-21bd-4a67-9490-0d58439203fc', metadata={'city': 'Peshawar', 'team': 'Peshawar Zalmi', 'source': 'social_media_analysis', 'category': 'fan_culture'}, page_content="Peshawar Zalmi's 'Yellow Storm' fan base is considered one of the most passionate in the league.")]

# %%
print(results[0].page_content)
# Out:
# LangChain is used to build LLM based applications.

# %%
print(results[1].page_content)
# Out:
# MMR helps you get diverse results when doing similarity search.

# %%
print(results[2].page_content)
# Out:
# Peshawar Zalmi's 'Yellow Storm' fan base is considered one of the most passionate in the league.

# %% [markdown]
# MULTI QUERY RETRIEVERS

# %%
# Relevant health & wellness documents
all_docs = [
    Document(page_content="Regular walking boosts heart health and can reduce symptoms of depression.", metadata={"source": "H1"}),
    Document(page_content="Consuming leafy greens and fruits helps detox the body and improve longevity.", metadata={"source": "H2"}),
    Document(page_content="Deep sleep is crucial for cellular repair and emotional regulation.", metadata={"source": "H3"}),
    Document(page_content="Controlled breathing lower cortisol and improve mental clarity.", metadata={"source": "H4"}),
    Document(page_content="Drinking sufficient water throughout the day helps maintain metabolism and energy.", metadata={"source": "H5"}),
    Document(page_content="The solar energy system in modern homes helps balance electricity demand.", metadata={"source": "I1"}),
    Document(page_content="Python balances readability with power, making it a popular system design language.", metadata={"source": "I2"}),
    Document(page_content="Photosynthesis enables plants to produce energy by converting sunlight.", metadata={"source": "I3"}),
    Document(page_content="The 2022 FIFA World Cup was held in Qatar and drew global energy and excitement.", metadata={"source": "I4"}),
    Document(page_content="Black holes bend spacetime and store immense gravitational energy.", metadata={"source": "I5"}),
]

# %%
embeddings = GoogleGenerativeAIEmbeddings(model="gemini-embedding-001",google_api_key='embeddings = GoogleGenerativeAIEmbeddings(model="gemini-embedding-001",google_api_key='AIzaSyBJ4Q0Hv0RYhWvTcS-UNbUZ0jROMlILx6k')-')

# %%
vector_store=Chroma.from_documents(documents=all_docs,embedding=embeddings,persist_directory='my_chromaDB',collection_name='sample')

# %%
res=vector_store.as_retriever(search_type='similarity',search_kwargs={"k":5})

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

# %%
from langchain_classic.retrievers import MultiQueryRetriever

# %%
model=ChatGoogleGenerativeAI(api_key='AIzaSyBJ4Q0Hv0RYhWvTcS-UNbUZ0jROMlILx6k',model='gemini-2.5-flash-lite')

# %%
multi=MultiQueryRetriever.from_llm(retriever=res,llm=model)

# %%
query='how to improve energy level and maintain balance'

# %%
res1=res.invoke(query)

# %%
res2=multi.invoke(query)

# %%
for i,doc in enumerate(res1):
  print("\n---Simple results---",i+1)
  print(doc.page_content)
# Out:
# ---Simple results--- 1
# Drinking sufficient water throughout the day helps maintain metabolism and energy.
#
# ---Simple results--- 2
# The solar energy system in modern homes helps balance electricity demand.
#
# ---Simple results--- 3
# Controlled breathing lower cortisol and improve mental clarity.
#
# ---Simple results--- 4
# Consuming leafy greens and fruits helps detox the body and improve longevity.
#
# ---Simple results--- 5
# Regular walking boosts heart health and can reduce symptoms of depression.

# %%
for i,doc in enumerate(res2):
  print("\n---Multi Query results---",i+1)
  print(doc.page_content)
# Out:
# ---Multi Query results--- 1
# Drinking sufficient water throughout the day helps maintain metabolism and energy.
#
# ---Multi Query results--- 2
# Regular walking boosts heart health and can reduce symptoms of depression.
#
# ---Multi Query results--- 3
# Controlled breathing lower cortisol and improve mental clarity.
#
# ---Multi Query results--- 4
# Consuming leafy greens and fruits helps detox the body and improve longevity.
#
# ---Multi Query results--- 5
# The solar energy system in modern homes helps balance electricity demand.
#
# ---Multi Query results--- 6
# Deep sleep is crucial for cellular repair and emotional regulation.
